# %% [markdown]
# # GAIA DR2

# %%
import numpy as np
import pandas as pd
from astroquery.gaia import Gaia
#Gaia.login(user='rgalvez',password='1624354abSN!#')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# Created TAP+ (v1.0.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
# <style>.container { width:98% !important; }</style>

# %%
# %%time

qry = """
SELECT top 1
max(bnb.source_id)as maximumn, min(bnb.source_id) as minimum
FROM gaiadr2.allwise_best_neighbour as bnb
"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()

largest, smallest = data.astype('long').values[0]
# Out:
# Query finished.
# CPU times: user 12.8 ms, sys: 848 µs, total: 13.7 ms
# Wall time: 761 ms

# %%
data = pd.DataFrame()

for i, k in enumerate(range(smallest, largest, largest//1000)):
    
    if i > 830:
        
        qry = """
        SELECT 
        allwise.source_id,
        allwise.original_ext_source_id,
        w1mpro,
        w1mpro_error,
        w2mpro,
        w2mpro_error,
        w3mpro,
        w3mpro_error,
        w4mpro,
        w4mpro_error,
        cc_flags,
        ext_flag,
        var_flag,
        ph_qual,
        w1mjd_mean,
        w2mjd_mean,
        w3mjd_mean,
        w4mjd_mean,
        w1gmag,
        w1gmag_error,
        w2gmag,
        w2gmag_error,
        w3gmag,
        w3gmag_error,
        w4gmag,
        w4gmag_error,
        l, b, dr2.ra, dr2.dec,
        phot_g_mean_mag, bp_rp, bp_g, g_rp,
        pmdec, pmra,
        parallax,
        parallax_over_error

        FROM gaiadr2.allwise_best_neighbour as allwise
        JOIN gaiadr2.gaia_source as dr2 on allwise.source_id = dr2.source_id
        JOIN gaiadr1.allwise_original_valid as original on original.allwise_oid = allwise.allwise_oid

        WHERE allwise.source_id between {} and {}

        """.format(k, k + largest//1000)
        data2 = Gaia.launch_job_async(qry).get_results().to_pandas()
        data  = pd.concat([data, data2], axis=0)
        print(data.shape[0], )
        print(k / largest * 100)

        if i % 10 == 0:
            data.to_csv('/bigdata1/gaia/dr2_allwise_crossmatch_part_{}.csv'.format(i))
            data = pd.DataFrame()
            print('successfully saved file at i = {}'.format(i))
        
data.to_csv('/bigdata1/gaia/dr2_allwise_crossmatch_part_{}.csv'.format(i))
data = pd.DataFrame()
del data2
print('successfully saved file at i = {}'.format(i))
print(data.shape)
# Out:
# Query finished.
# 623200
# 44.1000000621003
# Query finished.
# 1178159
# 44.2000000621003
# Query finished.
# 1551745
# 44.3000000621003
# Query finished.
# 1802120
# 44.4000000621003
# Query finished.
# 2168277
# 44.500000062100305
# Query finished.
# 2555509
# 44.60000006210031
# Query finished.
# 2865538
# 44.7000000621003
# Query finished.
# 3507730
# 44.8000000621003
# Query finished.
# 4154186
# 44.900000062100304
# Query finished.
# 4779076
# 45.0000000621003
# successfully saved file at i = 450
# Query finished.
# 591124
# 45.10000006210031
# Query finished.
# 1201539
# 45.2000000621003
# Query finished.
# 1714832
# 45.300000062100295
# Query finished.
# 2109384
# 45.400000062100304
# Query finished.
# 2517911
# 45.5000000621003
# Query finished.
# 3067739
# 45.6000000621003
# Query finished.
# 3461858
# 45.7000000621003
# Query finished.
# 3669839
# 45.800000062100295
# Query finished.
# 3811367
# 45.9000000621003
# Query finished.
# 3982356
# 46.000000062100305
# successfully saved file at i = 460
# Query finished.
# 114170
# 46.1000000621003
# Query finished.
# 260145
# 46.2000000621003
# Query finished.
# 446713
# 46.3000000621003
# Query finished.
# 682259
# 46.4000000621003
# Query finished.
# 1001066
# 46.5000000621003
# Query finished.
# 1243754
# 46.60000006210029
# Query finished.
# 1520745
# 46.7000000621003
# Query finished.
# 1776422
# 46.8000000621003
# Query finished.
# 1879263
# 46.9000000621003
# Query finished.
# 2005446
# 47.0000000621003
# successfully saved file at i = 470
# Query finished.
# 107006
# 47.1000000621003
# Query finished.
# 207573
# 47.200000062100294
# Query finished.
# 327012
# 47.3000000621003
# Query finished.
# 504173
# 47.400000062100304
# Query finished.
# 767208
# 47.5000000621003
# Query finished.
# 983449
# 47.6000000621003
# Query finished.
# 1149539
# 47.7000000621003
# Query finished.
# 1370281
# 47.800000062100295
# Query finished.
# 1820720
# 47.900000062100304
# Query finished.
# 2389880
# 48.0000000621003
# successfully saved file at i = 480
# Query finished.
# 582224
# 48.10000006210029
# Query finished.
# 1026850
# 48.2000000621003
# Query finished.
# 1615303
# 48.3000000621003
# Query finished.
# 2217351
# 48.4000000621003
# Query finished.
# 2789210
# 48.5000000621003
# Query finished.
# 3233073
# 48.6000000621003
# Query finished.
# 3843733
# 48.700000062100294
# Query finished.
# 4372868
# 48.8000000621003
# Query finished.
# 4832648
# 48.900000062100304
# Query finished.
# 5252936
# 49.0000000621003
# successfully saved file at i = 490
# Query finished.
# 564659
# 49.1000000621003
# Query finished.
# 959657
# 49.2000000621003
# Query finished.
# 1396393
# 49.300000062100295
# Query finished.
# 1920634
# 49.400000062100304
# Query finished.
# 2549904
# 49.500000062100305
# Query finished.
# 3125306
# 49.6000000621003
# Query finished.
# 3712165
# 49.7000000621003
# Query finished.
# 4334882
# 49.8000000621003
# Query finished.
# 4899028
# 49.9000000621003
# Query finished.
# 5232715
# 50.000000062100305
# successfully saved file at i = 500
# Query finished.
# 267293
# 50.1000000621003
# Query finished.
# 515794
# 50.2000000621003
# Query finished.
# 749200
# 50.3000000621003
# Query finished.
# 943586
# 50.400000062100304
# Query finished.
# 1145118
# 50.500000062100305
# Query finished.
# 1327527
# 50.60000006210031
# Query finished.
# 1491600
# 50.7000000621003
# Query finished.
# 1649967
# 50.8000000621003
# Query finished.
# 1795359
# 50.900000062100304
# Query finished.
# 1974963
# 51.000000062100305
# successfully saved file at i = 510
# Query finished.
# 185078
# 51.10000006210031
# Query finished.
# 339372
# 51.200000062100294
# Query finished.
# 510690
# 51.3000000621003
# Query finished.
# 653323
# 51.400000062100304
# Query finished.
# 785683
# 51.50000006210029
# Query finished.
# 913816
# 51.60000006210031
# Query finished.
# 1032619
# 51.7000000621003
# Query finished.
# 1150103
# 51.800000062100295
# Query finished.
# 1258842
# 51.900000062100304
# Query finished.
# 1371252
# 52.00000006210029
# successfully saved file at i = 520
# Query finished.
# 152352
# 52.10000006210029
# Query finished.
# 301333
# 52.2000000621003
# Query finished.
# 434833
# 52.300000062100295
# Query finished.
# 558177
# 52.4000000621003
# Query finished.
# 675630
# 52.500000062100305
# Query finished.
# 819973
# 52.60000006210029
# Query finished.
# 963839
# 52.700000062100294
# Query finished.
# 1093211
# 52.8000000621003
# Query finished.
# 1208105
# 52.9000000621003
# Query finished.
# 1324425
# 53.00000006210029
# successfully saved file at i = 530
# Query finished.
# 112361
# 53.10000006210031
# Query finished.
# 218278
# 53.200000062100294
# Query finished.
# 319250
# 53.300000062100295
# Query finished.
# 414240
# 53.400000062100304
# Query finished.
# 504834
# 53.5000000621003
# Query finished.
# 600448
# 53.60000006210029
# Query finished.
# 697283
# 53.70000006210031
# Query finished.
# 794885
# 53.800000062100295
# Query finished.
# 884561
# 53.9000000621003
# Query finished.
# 971375
# 54.000000062100305
# successfully saved file at i = 540
# Query finished.
# 108175
# 54.10000006210029
# Query finished.
# 248514
# 54.200000062100294
# Query finished.
# 369468
# 54.30000006210031
# Query finished.
# 503004
# 54.4000000621003
# Query finished.
# 630570
# 54.5000000621003
# Query finished.
# 738993
# 54.60000006210031
# Query finished.
# 840214
# 54.700000062100294
# Query finished.
# 932886
# 54.800000062100295
# Query finished.
# 1024438
# 54.900000062100304
# Query finished.
# 1116310
# 55.0000000621003
# successfully saved file at i = 550
# Query finished.
# 82237
# 55.10000006210029
# Query finished.
# 220922
# 55.20000006210031
# Query finished.
# 340241
# 55.300000062100295
# Query finished.
# 464430
# 55.4000000621003
# Query finished.
# 607796
# 55.500000062100305
# Query finished.
# 719872
# 55.6000000621003
# Query finished.
# 815978
# 55.700000062100294
# Query finished.
# 903851
# 55.80000006210031
# Query finished.
# 985414
# 55.9000000621003
# Query finished.
# 1076424
# 56.0000000621003
# successfully saved file at i = 560
# Query finished.
# 81426
# 56.1000000621003
# Query finished.
# 165406
# 56.200000062100294
# Query finished.
# 249006
# 56.300000062100295
# Query finished.
# 329449
# 56.4000000621003
# Query finished.
# 406873
# 56.5000000621003
# Query finished.
# 482499
# 56.6000000621003
# Query finished.
# 556731
# 56.7000000621003
# Query finished.
# 634255
# 56.800000062100295
# Query finished.
# 714036
# 56.9000000621003
# Query finished.
# 788167
# 57.0000000621003
# successfully saved file at i = 570
# Query finished.
# 71411
# 57.1000000621003
# Query finished.
# 142848
# 57.2000000621003
# Query finished.
# 216561
# 57.300000062100295
# Query finished.
# 287513
# 57.4000000621003
# Query finished.
# 358802
# 57.5000000621003
# Query finished.
# 430763
# 57.6000000621003
# Query finished.
# 498968
# 57.7000000621003
# Query finished.
# 567086
# 57.800000062100295
# Query finished.
# 635122
# 57.9000000621003
# Query finished.
# 701114
# 58.0000000621003
# successfully saved file at i = 580
# Query finished.
# 65165
# 58.1000000621003
# Query finished.
# 131195
# 58.2000000621003
# Query finished.
# 544106
# 58.300000062100295
# Query finished.
# 1063401
# 58.4000000621003
# Query finished.
# 1587201
# 58.5000000621003
# Query finished.
# 2001889
# 58.6000000621003
# Query finished.
# 2448349
# 58.7000000621003
# Query finished.
# 2954650
# 58.8000000621003
# Query finished.
# 3568191
# 58.9000000621003
# Query finished.
# 4240776
# 59.0000000621003
# successfully saved file at i = 590
# Query finished.
# 506173
# 59.1000000621003
# Query finished.
# 1006914
# 59.2000000621003
# Query finished.
# 1541268
# 59.3000000621003
# Query finished.
# 2123895
# 59.4000000621003
# Query finished.
# 2648123
# 59.5000000621003
# Query finished.
# 3283441
# 59.6000000621003
# Query finished.
# 3905059
# 59.7000000621003
# Query finished.
# 4536366
# 59.8000000621003
# Query finished.
# 5049324
# 59.900000062100304
# Query finished.
# 5469236
# 60.0000000621003
# successfully saved file at i = 600
# Query finished.
# 555472
# 60.1000000621003
# Query finished.
# 1166159
# 60.2000000621003
# Query finished.
# 1741081
# 60.3000000621003
# Query finished.
# 2408508
# 60.400000062100304
# Query finished.
# 3053704
# 60.5000000621003
# Query finished.
# 3709075
# 60.6000000621003
# Query finished.
# 4347417
# 60.70000006210029
# Query finished.
# 5009673
# 60.8000000621003
# Query finished.
# 5572909
# 60.900000062100304
# Query finished.
# 6106016
# 61.00000006210029
# successfully saved file at i = 610
# Query finished.
# 477445
# 61.1000000621003
# Query finished.
# 1139863
# 61.2000000621003
# Query finished.
# 1767943
# 61.30000006210029
# Query finished.
# 2365808
# 61.400000062100304
# Query finished.
# 2811281
# 61.5000000621003
# Query finished.
# 3334667
# 61.60000006210029
# Query finished.
# 3826715
# 61.7000000621003
# Query finished.
# 4321804
# 61.8000000621003
# Query finished.
# 4878852
# 61.90000006210029
# Query finished.
# 5475754
# 62.000000062100305
# successfully saved file at i = 620
# Query finished.
# 652015
# 62.1000000621003
# Query finished.
# 1143042
# 62.200000062100294
# Query finished.
# 1655312
# 62.3000000621003
# Query finished.
# 2120057
# 62.400000062100304
# Query finished.
# 2619331
# 62.50000006210029
# Query finished.
# 3146553
# 62.6000000621003
# Query finished.
# 3580657
# 62.7000000621003
# Query finished.
# 3919526
# 62.800000062100295
# Query finished.
# 4298853
# 62.900000062100304
# Query finished.
# 4831492
# 63.000000062100305
# successfully saved file at i = 630
# Query finished.
# 580745
# 63.10000006210029
# Query finished.
# 1159654
# 63.2000000621003
# Query finished.
# 1604319
# 63.3000000621003
# Query finished.
# 2102753
# 63.40000006210029
# Query finished.
# 2444404
# 63.500000062100305
# Query finished.
# 2681811
# 63.60000006210031
# Query finished.
# 2947942
# 63.700000062100294
# Query finished.
# 3137278
# 63.8000000621003
# Query finished.
# 3340722
# 63.900000062100304
# Query finished.
# 3585569
# 64.0000000621003
# successfully saved file at i = 640
# Query finished.
# 310651
# 64.1000000621003
# Query finished.
# 660252
# 64.2000000621003
# Query finished.
# 906660
# 64.3000000621003
# Query finished.
# 1138206
# 64.4000000621003
# Query finished.
# 1439162
# 64.5000000621003
# Query finished.
# 2092640
# 64.60000006210029
# Query finished.
# 2726328
# 64.7000000621003
# Query finished.
# 3353059
# 64.8000000621003
# Query finished.
# 3891636
# 64.90000006210029
# Query finished.
# 4477540
# 65.0000000621003
# successfully saved file at i = 650
# Query finished.
# 610011
# 65.10000006210029
# Query finished.
# 1185567
# 65.20000006210029
# Query finished.
# 1805337
# 65.3000000621003
# Query finished.
# 2424552
# 65.40000006210029
# Query finished.
# 3070433
# 65.5000000621003
# Query finished.
# 3525843
# 65.60000006210029
# Query finished.
# 3927061
# 65.7000000621003
# Query finished.
# 4328752
# 65.8000000621003
# Query finished.
# 4602890
# 65.90000006210029
# Query finished.
# 4912887
# 66.0000000621003
# successfully saved file at i = 660
# Query finished.
# 408047
# 66.10000006210029
# Query finished.
# 880470
# 66.2000000621003
# Query finished.
# 1375564
# 66.3000000621003
# Query finished.
# 1724259
# 66.40000006210029
# Query finished.
# 2082028
# 66.5000000621003
# Query finished.
# 2399839
# 66.60000006210029
# Query finished.
# 2657422
# 66.7000000621003
# Query finished.
# 2906059
# 66.80000006210031
# Query finished.
# 3128359
# 66.90000006210029
# Query finished.
# 3345008
# 67.0000000621003
# successfully saved file at i = 670
# Query finished.
# 188726
# 67.1000000621003
# Query finished.
# 716620
# 67.2000000621003
# Query finished.
# 1244919
# 67.3000000621003
# Query finished.
# 1515938
# 67.4000000621003
# Query finished.
# 1668913
# 67.5000000621003
# Query finished.
# 1809694
# 67.60000006210029
# Query finished.
# 2210057
# 67.7000000621003
# Query finished.
# 2408458
# 67.8000000621003
# Query finished.
# 2562287
# 67.90000006210029
# Query finished.
# 2708387
# 68.00000006210031
# successfully saved file at i = 680
# Query finished.
# 120171
# 68.10000006210029
# Query finished.
# 243206
# 68.2000000621003
# Query finished.
# 360449
# 68.30000006210031
# Query finished.
# 473214
# 68.4000000621003
# Query finished.
# 576597
# 68.5000000621003
# Query finished.
# 675445
# 68.6000000621003
# Query finished.
# 927012
# 68.7000000621003
# Query finished.
# 1130110
# 68.8000000621003
# Query finished.
# 1314617
# 68.9000000621003
# Query finished.
# 1460238
# 69.0000000621003
# successfully saved file at i = 690
# Query finished.
# 136803
# 69.10000006210029
# Query finished.
# 289528
# 69.20000006210032
# Query finished.
# 473521
# 69.3000000621003
# Query finished.
# 674515
# 69.4000000621003
# Query finished.
# 838953
# 69.5000000621003
# Query finished.
# 985947
# 69.60000006210029
# Query finished.
# 1259098
# 69.8000000621003
# Query finished.
# 1371450
# 69.9000000621003
# Query finished.
# 1474974
# 70.0000000621003
# successfully saved file at i = 700
# Query finished.
# 93555
# 70.10000006210029
# Query finished.
# 190739
# 70.2000000621003
# Query finished.
# 307361
# 70.3000000621003
# Query finished.
# 441327
# 70.4000000621003
# Query finished.
# 571847
# 70.5000000621003
# Query finished.
# 678351
# 70.60000006210029
# Query finished.
# 798445
# 70.7000000621003
# Query finished.
# 925827
# 70.8000000621003
# Query finished.
# 1041308
# 70.9000000621003
# Query finished.
# 1143716
# 71.0000000621003
# successfully saved file at i = 710
# Query finished.
# 110987
# 71.10000006210029
# Query finished.
# 207428
# 71.2000000621003
# Query finished.
# 298758
# 71.3000000621003
# Query finished.
# 388325
# 71.4000000621003
# Query finished.
# 474429
# 71.5000000621003
# Query finished.
# 558684
# 71.60000006210029
# Query finished.
# 639360
# 71.7000000621003
# Query finished.
# 724858
# 71.8000000621003
# Query finished.
# 822537
# 71.9000000621003
# Query finished.
# 909132
# 72.00000006210028
# successfully saved file at i = 720
# Query finished.
# 88002
# 72.1000000621003
# Query finished.
# 175203
# 72.20000006210029
# Query finished.
# 255631
# 72.3000000621003
# Query finished.
# 334107
# 72.4000000621003
# Query finished.
# 409035
# 72.50000006210028
# Query finished.
# 484505
# 72.60000006210029
# Query finished.
# 559140
# 72.7000000621003
# Query finished.
# 631848
# 72.8000000621003
# Query finished.
# 715863
# 72.90000006210029
# Query finished.
# 803449
# 73.0000000621003
# successfully saved file at i = 730
# Query finished.
# 93133
# 73.10000006210029
# Query finished.
# 169900
# 73.20000006210029
# Query finished.
# 248238
# 73.3000000621003
# Query finished.
# 339136
# 73.40000006210029
# Query finished.
# 436479
# 73.50000006210028
# Query finished.
# 542557
# 73.6000000621003
# Query finished.
# 627390
# 73.70000006210029
# Query finished.
# 721177
# 73.8000000621003
# Query finished.
# 806200
# 73.9000000621003
# Query finished.
# 877271
# 74.00000006210028
# successfully saved file at i = 740
# Query finished.
# 72355
# 74.10000006210029
# Query finished.
# 142476
# 74.2000000621003
# Query finished.
# 212401
# 74.3000000621003
# Query finished.
# 285137
# 74.40000006210029
# Query finished.
# 362862
# 74.5000000621003
# Query finished.
# 449037
# 74.60000006210029
# Query finished.
# 530097
# 74.70000006210029
# Query finished.
# 607299
# 74.80000006210031
# Query finished.
# 691652
# 74.90000006210029
# Query finished.
# 1062974
# 75.0000000621003
# successfully saved file at i = 750
# Query finished.
# 443225
# 75.1000000621003
# Query finished.
# 837774
# 75.20000006210029
# Query finished.
# 1163910
# 75.3000000621003
# Query finished.
# 1640746
# 75.4000000621003
# Query finished.
# 2198261
# 75.5000000621003
# Query finished.
# 2749649
# 75.60000006210029
# Query finished.
# 3238359
# 75.7000000621003
# Query finished.
# 3794524
# 75.8000000621003
# Query finished.
# 4276679
# 75.90000006210029
# Query finished.
# 4633830
# 76.0000000621003
# successfully saved file at i = 760
# Query finished.
# 375564
# 76.10000006210029
# Query finished.
# 838144
# 76.20000006210029
# Query finished.
# 1249133
# 76.30000006210031
# Query finished.
# 1647816
# 76.40000006210029
# Query finished.
# 2135052
# 76.5000000621003
# Query finished.
# 2698129
# 76.6000000621003
# Query finished.
# 3181869
# 76.70000006210029
# Query finished.
# 3727070
# 76.8000000621003
# Query finished.
# 4240038
# 76.9000000621003
# Query finished.
# 4700030
# 77.0000000621003
# successfully saved file at i = 770
# Query finished.
# 451372
# 77.10000006210029
# Query finished.
# 985674
# 77.2000000621003
# Query finished.
# 1516693
# 77.3000000621003
# Query finished.
# 2061406
# 77.40000006210029
# Query finished.
# 2664974
# 77.5000000621003
# Query finished.
# 3270503
# 77.60000006210029
# Query finished.
# 3758363
# 77.70000006210029
# Query finished.
# 4218410
# 77.80000006210031
# Query finished.
# 4675970
# 77.90000006210029
# Query finished.
# 5020047
# 78.0000000621003
# successfully saved file at i = 780
# Query finished.
# 489380
# 78.1000000621003
# Query finished.
# 1096589
# 78.2000000621003
# Query finished.
# 1639401
# 78.3000000621003
# Query finished.
# 2245659
# 78.4000000621003
# Query finished.
# 2788281
# 78.5000000621003
# Query finished.
# 3234763
# 78.60000006210029
# Query finished.
# 3588859
# 78.7000000621003
# Query finished.
# 3852416
# 78.8000000621003
# Query finished.
# 4188090
# 78.90000006210029
# Query finished.
# 4440287
# 79.00000006210031
# successfully saved file at i = 790
# Query finished.
# 257657
# 79.10000006210029
# Query finished.
# 558260
# 79.2000000621003
# Query finished.
# 982502
# 79.30000006210031
# Query finished.
# 1311545
# 79.40000006210029
# Query finished.
# 1647650
# 79.5000000621003
# Query finished.
# 2116261
# 79.6000000621003
# Query finished.
# 2678918
# 79.7000000621003
# Query finished.
# 3185473
# 79.8000000621003
# Query finished.
# 3759746
# 79.9000000621003
# Query finished.
# 4331287
# 80.0000000621003
# successfully saved file at i = 800
# Query finished.
# 591826
# 80.10000006210029
# Query finished.
# 895683
# 80.2000000621003
# Query finished.
# 1302339
# 80.3000000621003
# Query finished.
# 1696393
# 80.40000006210029
# Query finished.
# 1993736
# 80.50000006210031
# Query finished.
# 2408834
# 80.60000006210029
# Query finished.
# 2951078
# 80.7000000621003
# Query finished.
# 3560791
# 80.80000006210031
# Query finished.
# 4171980
# 80.9000000621003
# Query finished.
# 4773801
# 81.0000000621003
# successfully saved file at i = 810
# Query finished.
# 628830
# 81.1000000621003
# Query finished.
# 1247035
# 81.2000000621003
# Query finished.
# 1851563
# 81.3000000621003
# Query finished.
# 2315809
# 81.4000000621003
# Query finished.
# 2929875
# 81.5000000621003
# Query finished.
# 3466578
# 81.60000006210029
# Query finished.
# 3884474
# 81.70000006210029
# Query finished.
# 4168845
# 81.8000000621003
# Query finished.
# 4375305
# 81.9000000621003
# Query finished.
# 4630975
# 82.00000006210028
# successfully saved file at i = 820
# Query finished.
# 253686
# 82.10000006210029
# Query finished.
# 478009
# 82.2000000621003
# Query finished.
# 1125485
# 82.30000006210028
# Query finished.
# 1643966
# 82.4000000621003
# Query finished.
# 2196455
# 82.5000000621003
# Query finished.
# 2828592
# 82.60000006210029
# Query finished.
# 3352304
# 82.7000000621003
# Query finished.
# 3684024
# 82.8000000621003
# Query finished.
# 3920583
# 82.90000006210029
# Query finished.
# 4164121
# 83.0000000621003
# successfully saved file at i = 830
# Query finished.
# 328982
# 83.10000006210029
# Query finished.
# 553471
# 83.20000006210029
# Query finished.
# 897433
# 83.3000000621003
# Query finished.
# 1367558
# 83.4000000621003
# Query finished.
# 1918595
# 83.50000006210028
# Query finished.
# 2470827
# 83.60000006210029
# Query finished.
# 3116874
# 83.7000000621003
# Query finished.
# 3680618
# 83.80000006210028
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-3-3cbd4eea5918> in <module>()
#      46
#      47         """.format(k, k + largest//1000)
# ---> 48         data2 = Gaia.launch_job_async(qry).get_results().to_pandas()
#      49         data  = pd.concat([data, data2], axis=0)
#      50         print(data.shape[0], )
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/gaia/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name)
#     156                                                background=background,
#     157                                                upload_resource=upload_resource,
# --> 158                                                upload_table_name=upload_table_name)
#     159
#     160     def load_async_job(self, jobid=None, name=None, verbose=False):
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name)
#     336                     job.save_results(verbose)
#     337                 else:
# --> 338                     job.get_results()
#     339                     print("Query finished.")
#     340         return job
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/model/job.py in get_results(self)
#     524         else:
#     525             # async: result is in the server once the job is finished
# --> 526             self.__load_async_job_results()
#     527             return self.__results
#     528
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/model/job.py in __load_async_job_results(self, debug)
#     611         else:
#     612             outputFormat = self.get_output_format()
# --> 613             results = utils.read_http_response(resultsResponse, outputFormat)
#     614             self.set_results(results)
#     615             self.__phase = wjData
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/xmlparser/utils.py in read_http_response(response, outputFormat)
#      38         # 3.0
#      39         # If we want to use astropy.table, we have to read the data
# ---> 40         data = io.BytesIO(response.read())
#      41         return APTable.read(data, format=astropyFormat)
#      42
#
# /opt/anaconda37/lib/python3.7/http/client.py in read(self, amt)
#     458             else:
#     459                 try:
# --> 460                     s = self._safe_read(self.length)
#     461                 except IncompleteRead:
#     462                     self._close_conn()
#
# /opt/anaconda37/lib/python3.7/http/client.py in _safe_read(self, amt)
#     610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
# --> 612                 raise IncompleteRead(b''.join(s), amt)
#     613             s.append(chunk)
#     614             amt -= len(chunk)
#
# IncompleteRead: IncompleteRead(78742176 bytes read, 14924471 more expected)

# %%
# %%time
qry = """
SELECT TOP 2000000 dr2.random_index,
dr2.ra, 
dr2.dec, 
parallax, 
parallax_over_error, 
pmra, 
pmdec, 
ra_dec_corr, 
ra_parallax_corr, 
ra_pmra_corr, 
ra_pmdec_corr, 
dec_parallax_corr, 
dec_pmra_corr, 
dec_pmdec_corr, 
parallax_pmra_corr, 
parallax_pmdec_corr, 
pmra_pmdec_corr,  
phot_g_mean_mag,  
phot_bp_mean_mag, 
phot_rp_mean_mag, 
bp_rp, 
bp_g, 
g_rp

FROM gaiadr2.gaia_source as dr2

WHERE parallax_over_error > 100
AND parallax is not null
AND pmra is not null 
AND pmdec is not null
AND ra_dec_corr is not null
AND ra_parallax_corr is not null
AND ra_pmra_corr is not null
AND ra_pmdec_corr is not null
AND dec_parallax_corr is not null
AND dec_pmra_corr is not null
AND dec_pmdec_corr is not null
AND parallax_pmra_corr is not null
AND parallax_pmdec_corr is not null
AND pmra_pmdec_corr is not null
AND phot_g_mean_mag is not null  
AND phot_bp_mean_mag is not null
AND phot_rp_mean_mag is not null
AND bp_rp is not null
AND bp_g is not null
AND g_rp is not null

"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_clean.csv')
print(data.shape)
del data
# Out:
# Query finished.
# (2000000, 23)
# CPU times: user 2min 46s, sys: 2.47 s, total: 2min 49s
# Wall time: 11min 25s

# %%
# %%time
qry = """
SELECT TOP 2000000 dr2.random_index,
dr2.ra, 
dr2.dec, 
g_mean_psf_mag, 
r_mean_psf_mag, 
i_mean_psf_mag, 
z_mean_psf_mag, 
y_mean_psf_mag,

g_mean_psf_mag_error, 
r_mean_psf_mag_error, 
i_mean_psf_mag_error, 
z_mean_psf_mag_error, 
y_mean_psf_mag_error,

parallax, 
parallax_over_error, 
pmra, 
pmdec, 
ra_dec_corr, 
ra_parallax_corr, 
ra_pmra_corr, 
ra_pmdec_corr, 
dec_parallax_corr, 
dec_pmra_corr, 
dec_pmdec_corr, 
parallax_pmra_corr, 
parallax_pmdec_corr, 
pmra_pmdec_corr,  
phot_g_mean_mag,  
phot_bp_mean_mag, 
phot_rp_mean_mag, 
bp_rp, 
bp_g, 
g_rp

FROM gaiadr2.panstarrs1_original_valid as ps_ov 
JOIN gaiadr2.panstarrs1_best_neighbour as ps_bn on ps_bn.original_ext_source_id = ps_ov.obj_id
JOIN gaiadr2.gaia_source               as dr2   on dr2.source_id = ps_bn.source_id

WHERE parallax_over_error > 100

AND g_mean_psf_mag is not null
AND r_mean_psf_mag is not null
AND i_mean_psf_mag is not null
AND z_mean_psf_mag is not null
AND y_mean_psf_mag is not null
AND y_mean_psf_mag_error is not null
AND g_mean_psf_mag_error is not null
AND r_mean_psf_mag_error is not null
AND i_mean_psf_mag_error is not null
AND z_mean_psf_mag_error is not null
AND y_mean_psf_mag_error is not null
AND parallax is not null
AND parallax_over_error is not null 
AND pmra is not null 
AND pmdec is not null
AND ra_dec_corr is not null
AND ra_parallax_corr is not null
AND ra_pmra_corr is not null
AND ra_pmdec_corr is not null
AND dec_parallax_corr is not null
AND dec_pmra_corr is not null
AND dec_pmdec_corr is not null
AND parallax_pmra_corr is not null
AND parallax_pmdec_corr is not null
AND pmra_pmdec_corr is not null
AND phot_g_mean_mag is not null  
AND phot_bp_mean_mag is not null
AND phot_rp_mean_mag is not null
AND bp_rp is not null
AND bp_g is not null
AND g_rp is not null

"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_panstars_clean.csv')
data.shape
# Out:
# Query finished.
# CPU times: user 39.7 s, sys: 592 ms, total: 40.3 s
# Wall time: 5min 17s

# %%
del data

# %%
# %%time
qry = """
SELECT TOP 2000000 dr2.random_index,
dr2.ra, 
dr2.dec, 
g_mean_psf_mag, 
r_mean_psf_mag, 
i_mean_psf_mag, 
z_mean_psf_mag, 
y_mean_psf_mag,

g_mean_psf_mag_error, 
r_mean_psf_mag_error, 
i_mean_psf_mag_error, 
z_mean_psf_mag_error, 
y_mean_psf_mag_error,

parallax, 
parallax_over_error, 
pmra, 
pmdec, 
ra_dec_corr, 
ra_parallax_corr, 
ra_pmra_corr, 
ra_pmdec_corr, 
dec_parallax_corr, 
dec_pmra_corr, 
dec_pmdec_corr, 
parallax_pmra_corr, 
parallax_pmdec_corr, 
pmra_pmdec_corr,  
phot_g_mean_mag,  
phot_bp_mean_mag, 
phot_rp_mean_mag, 
bp_rp, 
bp_g, 
g_rp

FROM gaiadr2.panstarrs1_original_valid as ps_ov 
JOIN gaiadr2.panstarrs1_best_neighbour as ps_bn on ps_bn.original_ext_source_id = ps_ov.obj_id
JOIN gaiadr2.gaia_source               as dr2   on dr2.source_id = ps_bn.source_id

WHERE parallax is not null
AND g_mean_psf_mag is not null
AND r_mean_psf_mag is not null
AND i_mean_psf_mag is not null
AND z_mean_psf_mag is not null
AND y_mean_psf_mag_error is not null
AND g_mean_psf_mag_error is not null
AND r_mean_psf_mag_error is not null
AND i_mean_psf_mag_error is not null
AND z_mean_psf_mag_error is not null
AND y_mean_psf_mag_error is not null
AND parallax is not null
AND parallax_over_error is not null 
AND pmra is not null 
AND pmdec is not null
AND ra_dec_corr is not null
AND ra_parallax_corr is not null
AND ra_pmra_corr is not null
AND ra_pmdec_corr is not null
AND dec_parallax_corr is not null
AND dec_pmra_corr is not null
AND dec_pmdec_corr is not null
AND parallax_pmra_corr is not null
AND parallax_pmdec_corr is not null
AND pmra_pmdec_corr is not null
AND phot_g_mean_mag is not null  
AND phot_bp_mean_mag is not null
AND phot_rp_mean_mag is not null
AND bp_rp is not null
AND bp_g is not null
AND g_rp is not null

"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_panstars_unclean.csv')
data.shape
# Out:
# Query finished.
# CPU times: user 3min 54s, sys: 3.9 s, total: 3min 58s
# Wall time: 31min 32s

# %%
del data

# %%
# %%time
qry = """
SELECT TOP 2000000 dr2.random_index,
dr2.ra, 
dr2.dec, 
g_mean_psf_mag, 
r_mean_psf_mag, 
i_mean_psf_mag, 
z_mean_psf_mag, 
y_mean_psf_mag,

g_mean_psf_mag_error, 
r_mean_psf_mag_error, 
i_mean_psf_mag_error, 
z_mean_psf_mag_error, 
y_mean_psf_mag_error,

parallax, 
parallax_over_error, 
pmra, 
pmdec, 
ra_dec_corr, 
ra_parallax_corr, 
ra_pmra_corr, 
ra_pmdec_corr, 
dec_parallax_corr, 
dec_pmra_corr, 
dec_pmdec_corr, 
parallax_pmra_corr, 
parallax_pmdec_corr, 
pmra_pmdec_corr,  
phot_g_mean_mag,  
phot_bp_mean_mag, 
phot_rp_mean_mag, 
bp_rp, 
bp_g, 
g_rp

FROM gaiadr2.panstarrs1_original_valid as ps_ov 
JOIN gaiadr2.panstarrs1_best_neighbour as ps_bn on ps_bn.original_ext_source_id = ps_ov.obj_id
JOIN gaiadr2.gaia_source               as dr2   on dr2.source_id = ps_bn.source_id

WHERE parallax is not null
AND g_mean_psf_mag is not null
AND r_mean_psf_mag is not null
AND i_mean_psf_mag is not null
AND z_mean_psf_mag is not null
AND y_mean_psf_mag_error is not null
AND g_mean_psf_mag_error is not null
AND r_mean_psf_mag_error is not null
AND i_mean_psf_mag_error is not null
AND z_mean_psf_mag_error is not null
AND y_mean_psf_mag_error is not null
AND parallax is not null
AND parallax_over_error is not null 
AND pmra is not null 
AND pmdec is not null
AND ra_dec_corr is not null
AND ra_parallax_corr is not null
AND ra_pmra_corr is not null
AND ra_pmdec_corr is not null
AND dec_parallax_corr is not null
AND dec_pmra_corr is not null
AND dec_pmdec_corr is not null
AND parallax_pmra_corr is not null
AND parallax_pmdec_corr is not null
AND pmra_pmdec_corr is not null
AND phot_g_mean_mag is not null  
AND phot_bp_mean_mag is not null
AND phot_rp_mean_mag is not null
AND bp_rp is not null
AND bp_g is not null
AND g_rp is not null

"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_panstars_unclean.csv')
data.shape

# %%
del data

# %%
# %%time
qry = """
SELECT 
dr2.source_id, 
w1mpro,
w1mpro_error,
w2mpro,
w2mpro_error,
w3mpro',
w3mpro_error,
w4mpro,
w4mpro_error,
cc_flags,
ext_flag,
var_flag,
ph_qual,
w1mjd_mean,
w2mjd_mean,
w3mjd_mean,
w4mjd_mean,
w1gmag,
w1gmag_error,
w2gmag,
w2gmag_error,
w3gmag,
w3gmag_error,
w4gmag,
w4gmag_error

FROM gaiadr2.allwise_best_neighbour as allwise
JOIN gaiadr2.gaia_source as dr2 on allwise.source_id = dr2.source_id
JOIN gaiadr1.allwise_original_valid as original on original.allwise_oid = allwise.allwise_oid

"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
#data.to_csv('/bigdata1/gaia/dr2_allwise.csv')
print(data.shape)

# %%
data.head()
# Out:
#       source_id  original_ext_source_id  w1mpro  w1mpro_error  w2mpro  \
# 0  3.092381e+11  b'J025958.79+000217.4'  15.852         0.046  15.547
# 1  3.435974e+11  b'J025951.33+000236.8'  15.911         0.046  16.004
# 2  5.497558e+11  b'J030011.58+000253.7'  12.682         0.023  12.701
# 3  8.289295e+11  b'J030005.66+000406.3'  14.008         0.026  14.052
# 4  9.277131e+11  b'J030006.39+000454.0'  16.238         0.055  16.147
#
#    w2mpro_error  w3mpro  w3mpro_error  w4mpro  w4mpro_error  \
# 0         0.101  12.791           NaN   9.318           NaN
# 1         0.154  12.718           NaN   9.364           NaN
# 2         0.025  12.054         0.300   9.155           NaN
# 3         0.038  12.657         0.428   8.899           NaN
# 4         0.173  12.628           NaN   9.237           NaN
#
#           ...                    l          b phot_g_mean_mag     bp_rp  \
# 0         ...           176.914265 -48.879747       19.637150  2.705435
# 1         ...           176.875423 -48.898380       18.148487  1.291325
# 2         ...           176.959363 -48.834396       15.003798  1.270053
# 3         ...           176.911302 -48.838163       16.597059  1.479727
# 4         ...           176.900060 -48.826707       19.404552  1.897663
#
#        bp_g      g_rp      pmdec       pmra  parallax  parallax_over_error
# 0  1.453381  1.252054  -0.468559   0.918556  1.578841             3.501472
# 1  0.579281  0.712044  -1.592207   6.778646  0.112423             0.571341
# 2  0.562131  0.707922 -16.297422   0.776524  1.575741            34.676788
# 3  0.687414  0.792313 -10.492354  13.599615  1.150084             8.101219
# 4  0.856234  1.041430        NaN        NaN       NaN                  NaN
#
# [5 rows x 36 columns]

# %%
data = data.astype('long')

smallest = data.minimum
largest  = data.maximum

difference = largest - smallest
difference
# Out:
# 0    6917528993281577216
# dtype: int64

# %%
# %%time
qry = """
SELECT
source_id,
original_ext_source_id

FROM gaiadr2.allwise_best_neighbour

where ra is between {} and {}
""".format()
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_allwise_crossmatch.csv')
print(data.shape)
# Out:
# 500
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/gaia/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name)
#     156                                                background=background,
#     157                                                upload_resource=upload_resource,
# --> 158                                                upload_table_name=upload_table_name)
#     159
#     160     def load_async_job(self, jobid=None, name=None, verbose=False):
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name)
#     336                     job.save_results(verbose)
#     337                 else:
# --> 338                     job.get_results()
#     339                     print("Query finished.")
#     340         return job
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/model/job.py in get_results(self)
#     524         else:
#     525             # async: result is in the server once the job is finished
# --> 526             self.__load_async_job_results()
#     527             return self.__results
#     528
#
# /opt/anaconda37/lib/python3.7/site-packages/astroquery/utils/tap/model/job.py in __load_async_job_results(self, debug)
#     608         if isError:
#     609             print(resultsResponse.reason)
# --> 610             raise Exception(resultsResponse.reason)
#     611         else:
#     612             outputFormat = self.get_output_format()
#
# Exception: 500

# %%
data.shape
# Out:
# (3000000, 1)

# %%
# %%time
qry = """
SELECT dr2.source_id, l, b,
phot_g_mean_mag, bp_rp, bp_g, g_rp

FROM gaiadr2.gaia_source as dr2 
WHERE radial_velocity is not null
"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/dr2_rv_complement.csv')
print(data.shape)

# %%
complement = pd.read_csv('/bigdata1/gaia/dr2_allwise_rv_complement.csv').iloc[:,1:]
complement['source_id'] = complement.source_id.astype('long')

# %%
from astropy.io import fits
from astropy.table import Table

# %%
data = Table.read('/bigdata1/gaia/radial_velocity_sample/Marchetti_v0.1.fits').to_pandas()
data['source_id'] = data.source_id.astype('long')

# %%
data.set_index('source_id', inplace=True)
complement.set_index('source_id', inplace=True)

# %%
# %%time
data2 = data[data.index.isin(complement.index)]
print(data2.shape)
# Out:
# (1603504, 48)
# CPU times: user 3.91 s, sys: 285 ms, total: 4.2 s
# Wall time: 1.14 s

# %%
complement.tail(1).index == data.tail(1).index
# Out:
# array([False])

# %%
data.index.isin(complement.index).sum()
# Out:
# 1603504

# %%
complement.tail()
# Out:
#                      w1mpro  w1mpro_error  w2mpro  w2mpro_error  w3mpro  \
# source_id
# 6917441066711387136  10.813         0.023  10.913         0.020  10.646
# 6917449244329111552  11.444         0.022  11.482         0.022  11.261
# 6917452650238623744   9.744         0.023   9.796         0.021   9.762
# 6917467111393043456  11.311         0.022  11.373         0.022  11.353
# 6917523843616561152   9.913         0.022   9.957         0.020   9.853
#
#                      w3mpro_error  w4mpro  w4mpro_error    w1mjd_mean  \
# source_id
# 6917441066711387136         0.103   9.039           NaN  55406.820502
# 6917449244329111552         0.172   8.753           NaN  55411.085046
# 6917452650238623744         0.054   8.257           NaN  55407.868408
# 6917467111393043456         0.194   8.907           NaN  55418.382660
# 6917523843616561152         0.053   8.446           NaN  55415.010766
#
#                        w2mjd_mean    w3mjd_mean    w4mjd_mean          l  \
# source_id
# 6917441066711387136  55406.820502  55325.293087  55325.293087  48.295688
# 6917449244329111552  55411.085046  55325.293018  55325.293018  48.501439
# 6917452650238623744  55407.868408  55325.683930  55325.683930  48.760382
# 6917467111393043456  55418.382660  55324.841987  55324.841987  48.108465
# 6917523843616561152  55411.090799  55325.292960  55325.292960  48.787594
#
#                              b  phot_g_mean_mag     bp_rp      bp_g      g_rp
# source_id
# 6917441066711387136 -28.794962        13.328806  1.355224  0.617907  0.737316
# 6917449244329111552 -28.619758        12.858150  0.810725  0.328736  0.481989
# 6917452650238623744 -28.929388        11.306193  0.896421  0.379481  0.516940
# 6917467111393043456 -28.296211        12.912230  0.935438  0.394830  0.540608
# 6917523843616561152 -28.369582        11.117123  0.684642  0.273339  0.411303

# %%
data.head()[data.head().index.isin(complement.index)]
# Out:
#                        ra       dec  parallax  e_parallax       pmra  \
# source_id
# 2851858288640   45.132144  0.137851  2.618833    0.058603   4.782391
# 3332894779520   45.058167  0.127404  1.742291    0.049292   6.399016
# 7632157690368   45.034337  0.235391  5.692796    0.058828  45.377928
# 9281425163264   45.165008  0.200060  3.750882    0.060761   6.535621
# 12545600306304  45.234476  0.318159  4.257022    0.044182   0.037377
#
#                   e_pmra      pmdec   e_pmdec       vrad    e_vrad  ...   \
# source_id                                                           ...
# 2851858288640   0.092797  18.790212  0.080928  33.840437  1.473904  ...
# 3332894779520   0.076351 -12.942712  0.084556   4.572674  1.709269  ...
# 7632157690368   0.090056  -6.494226  0.078755   6.404075  0.190706  ...
# 9281425163264   0.083478 -53.396270  0.085442 -26.394058  0.586229  ...
# 12545600306304  0.071930 -48.288673  0.075689 -48.504973  2.373606  ...
#
#                        UW     el_UW     eu_UW         vR     el_vR     eu_vR  \
# source_id
# 2851858288640   29.875095  1.063727  0.978358  30.237784  1.131376  1.029477
# 3332894779520   18.332150  0.821607  0.856986 -17.313312  1.121078  1.108854
# 7632157690368   20.268789  0.243004  0.248679   9.606884  0.236312  0.236575
# 9281425163264   59.132725  0.572398  0.580229 -58.909873  0.579762  0.569233
# 12545600306304  74.305436  1.896763  2.012927 -71.714251  1.582333  1.569737
#
#                       vtot   el_vtot   eu_vtot  P_ub
# source_id
# 2851858288640   272.751037  0.523357  0.510135   0.0
# 3332894779520   213.336643  1.085285  0.946576   0.0
# 7632157690368   222.288083  0.289838  0.269930   0.0
# 9281425163264   202.306197  0.785855  0.710642   0.0
# 12545600306304  221.157714  0.696206  0.665785   0.0
#
# [5 rows x 48 columns]

# %%
data2.to_csv('/bigdata1/gaia/dr2_allwise_rv_marchetti.csv')

# %%
# %%time
qry = """
SELECT count(*)

FROM gaiadr2.allwise_best_neighbour    as aw_bn
JOIN gaiadr1.allwise_original_valid    as aw_ov on aw_ov.allwise_oid = aw_bn.allwise_oid
JOIN gaiadr2.gaia_source               as dr2   on dr2.source_id = aw_bn.source_id

WHERE parallax is not null
AND pmra is not null 
AND pmdec is not null
--AND ra_dec_corr is not null
--AND ra_parallax_corr is not null
--AND ra_pmra_corr is not null
--AND ra_pmdec_corr is not null
--AND dec_parallax_corr is not null
--AND dec_pmra_corr is not null
--AND dec_pmdec_corr is not null
--AND parallax_pmra_corr is not null
--AND parallax_pmdec_corr is not null
--AND pmra_pmdec_corr is not null
AND phot_g_mean_mag is not null  
AND phot_bp_mean_mag is not null
AND phot_rp_mean_mag is not null
AND bp_rp is not null
AND bp_g is not null
AND g_rp is not null
AND radial_velocity is not null
"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
# data.to_csv('dr2_allwise.csv')
# data.shape
# Out:
# Query finished.
# CPU times: user 1.07 s, sys: 372 ms, total: 1.44 s
# Wall time: 10min 54s

# %%
# %%time
qry = """
SELECT TOP 1000000 dr2.random_index, *
FROM gaiadr2.gaia_source as dr2
WHERE dr2.parallax is not null
AND dr2.pmra is not null
AND dr2.pmdec is not null
AND dr2.radial_velocity is not null
AND dr2.parallax_over_error > 100
"""
data = Gaia.launch_job_async(qry).get_results().to_pandas()
data.to_csv('/bigdata1/gaia/radial_velocity_dr2_clean.csv')
